# %%
#sort by roll number
students = {}

for i in range(5):
    roll_no = int(input(f"Enter roll number for student{i+1}:"))
    name = input(f"Enter name for student{i+1}:")
    students[roll_no] = name

asc_sorted = dict(sorted(students.items()))
desc_sorted = dict(sorted(students.items(), reverse=True))

print("\nOriginal Dictionary:", students)
print("Ascending order by roll no:", asc_sorted)
print("Descending order by roll no:", desc_sorted)
# Out:
# Enter roll number for student1:103
# Enter name for student1:anu
# Enter roll number for student2:105
# Enter name for student2:siya
# Enter roll number for student3:104
# Enter name for student3:miya
# Enter roll number for student4:108
# Enter name for student4:saja
# Enter roll number for student5:102
# Enter name for student5:sinu
#
# Original Dictionary: {103: 'anu', 105: 'siya', 104: 'miya', 108: 'saja', 102: 'sinu'}
# Ascending order by roll no: {102: 'sinu', 103: 'anu', 104: 'miya', 105: 'siya', 108: 'saja'}
# Descending order by roll no: {108: 'saja', 105: 'siya', 104: 'miya', 103: 'anu', 102: 'sinu'}

# %%
# merging two dictionaries
dic1 = {}

for i in range(3):
    roll_no = int(input(f"Enter roll number for student {i+1}: "))
    name = input(f"Enter name for student {i+1}: ")
    dic1[roll_no] = name
dic2 = {}

for i in range(2):
    roll_no = int(input(f"Enter roll number for student {i+1}: "))
    name = input(f"Enter name for student {i+1}: ")
    dic2[roll_no] = name

dic1.update(dic2)

print("\nMerged Dictionary:", dic1)
# Out:
# Enter roll number for student 1: 11
# Enter name for student 1: anu
# Enter roll number for student 2: 13
# Enter name for student 2: minnu
# Enter roll number for student 3: 18
# Enter name for student 3: sachu
# Enter roll number for student 1: 14
# Enter name for student 1: miya
# Enter roll number for student 2: 16
# Enter name for student 2: siya
#
# Merged Dictionary: {11: 'anu', 13: 'minnu', 18: 'sachu', 14: 'miya', 16: 'siya'}
