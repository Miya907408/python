# %%
#sort by roll number
students = {}

roll_no = int(input("Enter roll number for student 1: "))
name = input("Enter name for student 1: ")
students[roll_no] = name

roll_no = int(input("Enter roll number for student 2: "))
name = input("Enter name for student 2: ")
students[roll_no] = name

roll_no = int(input("Enter roll number for student 3: "))
name = input("Enter name for student 3: ")
students[roll_no] = name

roll_no = int(input("Enter roll number for student 4: "))
name = input("Enter name for student 4: ")
students[roll_no] = name

roll_no = int(input("Enter roll number for student 5: "))
name = input("Enter name for student 5: ")
students[roll_no] = name

asc_sorted = dict(sorted(students.items()))
desc_sorted = dict(sorted(students.items(), reverse=True))

print("\nOriginal Dictionary:", students)
print("Ascending order by roll no:", asc_sorted)
print("Descending order by roll no:", desc_sorted)
# Out:
# Enter roll number for student 1: 13
# Enter name for student 1: anu
# Enter roll number for student 2: 15
# Enter name for student 2: sinu
# Enter roll number for student 3: 14
# Enter name for student 3: rinu
# Enter roll number for student 4: 18
# Enter name for student 4: aynu
# Enter roll number for student 5: 12
# Enter name for student 5: minnu
#
# Original Dictionary: {13: 'anu', 15: 'sinu', 14: 'rinu', 18: 'aynu', 12: 'minnu'}
# Ascending order by roll no: {12: 'minnu', 13: 'anu', 14: 'rinu', 15: 'sinu', 18: 'aynu'}
# Descending order by roll no: {18: 'aynu', 15: 'sinu', 14: 'rinu', 13: 'anu', 12: 'minnu'}

# %%
# merging two dictionaries
dic1 = {}

roll_no = int(input("Enter roll number for student 1: "))
name = input("Enter name for student 1: ")
dic1[roll_no] = name

roll_no = int(input("Enter roll number for student 2: "))
name = input("Enter name for student 2: ")
dic1[roll_no] = name

roll_no = int(input("Enter roll number for student 3: "))
name = input("Enter name for student 3: ")
dic1[roll_no] = name


dic2 = {}

roll_no = int(input("Enter roll number for student 1: "))
name = input("Enter name for student 1: ")
dic2[roll_no] = name

roll_no = int(input("Enter roll number for student 2: "))
name = input("Enter name for student 2: ")
dic2[roll_no] = name
print("dictionary 1:",dic1)
print("dictionary 2:",dic2)


dic1.update(dic2)

print("\nMerged Dictionary:", dic1)
# Out:
# Enter roll number for student 1: 11
# Enter name for student 1: sinu
# Enter roll number for student 2: 12
# Enter name for student 2: rinu
# Enter roll number for student 3: 13
# Enter name for student 3: minnu
# Enter roll number for student 1: 15
# Enter name for student 1: aynu
# Enter roll number for student 2: 16
# Enter name for student 2: yuan
# dictionary 1: {11: 'sinu', 12: 'rinu', 13: 'minnu'}
# dictionary 2: {15: 'aynu', 16: 'yuan'}
#
# Merged Dictionary: {11: 'sinu', 12: 'rinu', 13: 'minnu', 15: 'aynu', 16: 'yuan'}
